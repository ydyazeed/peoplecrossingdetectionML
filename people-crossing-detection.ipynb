# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
#Loading the YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /Users/yazeedshamsudeen/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-8-21 Python-3.9.12 torch-1.12.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
model.classes = [0]
img = 'https://previews.123rf.com/images/giuseppemasci/giuseppemasci1605/giuseppemasci160502041/56926133-london-england-january-31-2012-people-crossing-the-street-near-the-abbey-road-studios.jpg'
result = model(img)
# %matplotlib inline 
plt.imshow(np.squeeze(result.render()))
plt.show()
